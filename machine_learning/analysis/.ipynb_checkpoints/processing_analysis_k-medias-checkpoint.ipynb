# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('../data/employees.csv',)

# %%
data.head(5)
# Out:
#    sale_day  customer_score  losses_day  Organization  Responsibility  \
# 0  81631.95               5      557.70             1               0
# 1  90569.99               4      627.89             0               1
# 2  93542.70               1      856.67             1               1
# 3  82687.10               3      834.14             1               0
# 4  95607.54               2      686.01             0               0
#
#    Conduct  Resource_management  Conflict_management  Contribution
# 0        0                    1                    0             1
# 1        0                    1                    1             1
# 2        1                    1                    1             0
# 3        1                    1                    0             0
# 4        1                    1                    1             0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   sale_day             1000 non-null   float64
#  1   customer_score       1000 non-null   int64
#  2   losses_day           1000 non-null   float64
#  3   Organization         1000 non-null   int64
#  4   Responsibility       1000 non-null   int64
#  5   Conduct              1000 non-null   int64
#  6   Resource_management  1000 non-null   int64
#  7   Conflict_management  1000 non-null   int64
#  8   Contribution         1000 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 70.4 KB

# %%
data.hist()
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
dataset = data.loc[0:,['sale_day','customer_score']].values

# %%
dataset
# Out:
# array([8.163195e+04, 9.056999e+04, 9.354270e+04, 8.268710e+04,
#        9.560754e+04, 4.309129e+04, 9.929666e+04, 8.135802e+04,
#        4.903690e+04, 7.030635e+04, 9.172306e+04, 8.544833e+04,
#        8.942945e+04, 3.542800e+02, 8.230000e+01, 1.740887e+04,
#        2.376574e+04, 5.819017e+04, 5.932923e+04, 9.317992e+04,
#        7.273115e+04, 7.431518e+04, 3.836993e+04, 2.878226e+04,
#        6.373480e+03, 1.414998e+04, 4.147796e+04, 5.785600e+03,
#        8.246979e+04, 7.773144e+04, 8.908439e+04, 5.035644e+04,
#        6.241785e+04, 3.503543e+04, 3.608014e+04, 4.140516e+04,
#        9.375411e+04, 1.280711e+04, 7.443400e+04, 4.081893e+04,
#        7.865400e+02, 2.857062e+04, 1.199893e+04, 6.772287e+04,
#        7.360026e+04, 7.809496e+04, 3.089420e+04, 2.978116e+04,
#        6.932699e+04, 2.044995e+04, 2.712437e+04, 3.000629e+04,
#        2.139789e+04, 1.298300e+04, 2.983631e+04, 4.355977e+04,
#        7.944941e+04, 2.861236e+04, 6.501013e+04, 9.691921e+04,
# ...
